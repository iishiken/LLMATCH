# %% [markdown]
# # 医療テキスト分析システム
#
# このノートブックでは以下の機能を実行できます：
#
# 1. LLMサーバーの起動確認
# 2. テキスト分析の実行
# 3. 結果の確認と保存

# %%
import sys
import os
import pandas as pd
import requests
from IPython.display import display
from openai import OpenAI

# srcディレクトリをパスに追加
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.data.data_generator import MedicalDataGenerator
from src.analyzer.excel_analyzer import ExcelAnalyzer

# %% [markdown]
# ## 1. LLMサーバーの起動確認
#
# **注意**: 別ターミナルで `python src/analyzer/llm_server.py` を実行してサーバーを起動しておく必要があります。

# %%
def check_llm_server():
    server_url = "http://localhost:8000"
    try:
        # ヘルスチェックエンドポイントを確認
        health_response = requests.get(f"{server_url}/health", timeout=5)
        if health_response.status_code == 200:
            print("✅ LLMサーバーが正常に動作しています")
            
            # APIエンドポイントも確認
            api_response = requests.get(f"{server_url}/v1/chat/completions", timeout=5)
            if api_response.status_code == 405:  # POSTメソッドのみ許可される場合
                print("✅ APIエンドポイントも利用可能です")
                return True
            else:
                print("⚠️ APIエンドポイントが応答しませんでした")
                print(f"ステータスコード: {api_response.status_code}")
                return False
    except requests.exceptions.ConnectionError:
        print("❌ LLMサーバーに接続できません")
        print(f"サーバーURL: {server_url}")
        print("\n以下を確認してください：")
        print("1. サーバーが起動しているか")
        print("2. URLが正しいか")
        print("3. ファイアウォールの設定")
        print("\nサーバー起動コマンド：")
        print("python src/analyzer/llm_server.py")
    except requests.exceptions.Timeout:
        print("❌ サーバーの応答がタイムアウトしました")
    except Exception as e:
        print(f"❌ 予期せぬエラーが発生しました: {str(e)}")
    return False

# サーバーの状態を確認
check_llm_server()
# Out:
# ✅ LLMサーバーが正常に動作しています
# ✅ APIエンドポイントも利用可能です
# True

# %% [markdown]
# ### テスト呼び出し

# %%
# OpenAIクライアントの初期化
client = OpenAI(
    api_key="EMPTY",
    base_url="http://localhost:8000/v1"
)

try:
    # テスト呼び出し
    completion = client.completions.create(
        model="Qwen/Qwen2.5-72B-Instruct-GPTQ-Int4",
        prompt="San Francisco is a"
    )
    print("✅ LLMサーバーのテスト呼び出しに成功しました")
    print("応答結果:", completion)
except Exception as e:
    print("❌ LLMサーバーのテスト呼び出しに失敗しました")
    print(f"エラー内容: {str(e)}")
# Out:
# ✅ LLMサーバーのテスト呼び出しに成功しました
# 応答結果: Completion(id='cmpl-b46586835c364f9e95776c40a247dd56', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' rock supergroup that formed in San Francisco, California, in 201', stop_reason=None, prompt_logprobs=None)], created=1739449171, model='Qwen/Qwen2.5-72B-Instruct-GPTQ-Int4', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=4, total_tokens=20, completion_tokens_details=None, prompt_tokens_details=None))

# %% [markdown]
# ## 2. テキスト分析の実行
#
# 生成したデータに対して、各種分析を実行します。

# %% [markdown]
# 患者データとプロンプトテンプレート読み込み

# %%
# アナライザーの初期化
try:
    # データディレクトリの作成（存在しない場合）
    os.makedirs("data", exist_ok=True)
    
    # ファイルパスの設定
    data_file = "data/sample_data.xlsx"
    template_file = "templates/prompt_templates.json"
    
    analyzer = ExcelAnalyzer(
        llm_server_url="http://localhost:8000/v1",
        template_path=template_file
    )
    
    # ファイルの読み込み
    if not analyzer.load_excel(data_file):
        print("❌ ファイルの読み込みに失敗しました")
    else:
        print("✅ ファイルの読み込みが完了しました")
        analyzer.display_data_info()
except Exception as e:
    print(f"❌ エラーが発生しました: {str(e)}")
    print("以下を確認してください：")
    print(f"1. {template_file} ファイルが存在すること")
    print(f"2. {data_file} ファイルが存在すること")
    print("3. LLMサーバーが起動していること")
# Out:
# テンプレートを読み込みました（7件）
# ファイルの読み込みが完了しました
# ✅ ファイルの読み込みが完了しました
# データ行数: 489
#
# 列一覧:
# - ID
# - day
# - text

# %% [markdown]
# IDごとにまとめれた患者記載の確認

# %%
# ExcelAnalyzerのインスタンスを作成
analyzer = ExcelAnalyzer()

# Excelファイルを読み込む
analyzer.load_excel("data/sample_data.xlsx")

# すべてのIDのまとめられたテキストを取得
all_texts = analyzer.get_combined_texts()

# 特定のIDのテキストのみを取得
specific_id = "1"
single_text = analyzer.get_combined_texts(specific_id)

# 結果の表示例
for id_val, text in all_texts.items():
    print(f"ID: {id_val}")
    print("テキスト:")
    print(text)
    print("-" * 50)
# Out:
# ファイルの読み込みが完了しました
# 警告: ID '1' が見つかりません
# ID: 1
# テキスト:
# [2023-01-01]
# 組織診の結果、体部類内膜癌、Stage IVBと診断。 抗凝固薬（イグザレルト）服用中
#
# [2023-01-11]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-10]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間187分、出血量214ml。
#
# [2023-02-20]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 抗凝固薬（イグザレルト）服用中
#
# [2023-03-05]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 糖尿病（HbA1c 9.1%）あり
#
# [2023-03-13]
# 術後化学療法として毎週パクリタキセルを開始。 心機能低下（EF 55%）あり
# --------------------------------------------------
# ID: 2
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、明細胞癌、Stage IIIAと診断。
#
# [2023-01-30]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-18]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間340分、出血量728ml。
# --------------------------------------------------
# ID: 3
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、漿液性卵巣癌、Stage IVCと診断。 高度肥満（BMI 31.6）
#
# [2023-01-28]
# 治療方針：開腹子宮全摘の方針。
#
# [2023-02-16]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間321分、出血量767ml。
# --------------------------------------------------
# ID: 4
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮体がん、Stage IIAと診断。 腎機能低下（Cr 1.8 mg/dl）
#
# [2023-01-24]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-12]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間162分、出血量164ml。
#
# [2023-02-21]
# 術後化学療法としてweekly PTXを開始。 糖尿病（HbA1c 8.2%）あり
# --------------------------------------------------
# ID: 5
# テキスト:
# [2023-01-01]
# 生検の結果、子宮体癌、Stage IIIBと診断。
#
# [2023-01-25]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-10]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間140分、出血量948ml。
#
# [2023-03-04]
# 術後化学療法としてDTX+CBDCAを開始。
# --------------------------------------------------
# ID: 6
# テキスト:
# [2023-01-01]
# 組織診の結果、卵巣腫瘍、Stage IVAと診断。
#
# [2023-01-16]
# 治療方針：開腹子宮全摘の方針。
#
# [2023-02-03]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間131分、出血量622ml。
#
# [2023-02-25]
# 術後化学療法としてDTX+CBDCAを開始。 糖尿病（HbA1c 9.8%）あり
#
# [2023-03-09]
# 術後化学療法としてDTX+CBDCAを開始。
#
# [2023-03-21]
# 術後化学療法としてTC療法を開始。 高度肥満（BMI 34.7）
#
# [2023-04-16]
# 術後化学療法としてweekly PTXを開始。
# --------------------------------------------------
# ID: 7
# テキスト:
# [2023-01-01]
# 生検の結果、卵巣腫瘍、Stage IIAと診断。
#
# [2023-01-28]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-02-10]
# 手術記録：開腹子宮摘出術施行。手術時間127分、出血量68ml。
#
# [2023-02-21]
# 術後化学療法としてDTX+CBDCAを開始。 糖尿病（HbA1c 7.6%）あり
#
# [2023-03-10]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
#
# [2023-03-23]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 8
# テキスト:
# [2023-01-01]
# 生検の結果、子宮体部癌、Stage IVAと診断。 抗凝固薬（イグザレルト）服用中
#
# [2023-01-13]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-05]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間327分、出血量565ml。
#
# [2023-02-19]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 高度肥満（BMI 39.8）
# --------------------------------------------------
# ID: 9
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、卵巣腫瘍、Stage ICと診断。 腎機能低下（Cr 2.8 mg/dl）
#
# [2023-01-16]
# 治療方針：開腹全摘術の方針。
#
# [2023-01-28]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間147分、出血量426ml。
#
# [2023-02-16]
# 術後化学療法としてweekly パクリタキセルを開始。 心機能低下（EF 53%）あり
#
# [2023-03-03]
# 術後化学療法としてTCを開始。
# --------------------------------------------------
# ID: 10
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮頚癌、Stage IVAと診断。
#
# [2023-01-26]
# 治療方針：腹腔鏡下全摘術の方針。 心機能低下（EF 46%）あり
#
# [2023-02-12]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間303分、出血量621ml。
#
# [2023-03-06]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-03-30]
# 術後化学療法としてDC療法を開始。
#
# [2023-04-20]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 11
# テキスト:
# [2023-01-01]
# 組織診の結果、卵巣がん、Stage IIIAと診断。 心機能低下（EF 32%）あり
#
# [2023-01-22]
# 治療方針：開腹子宮摘出術の方針。 心機能低下（EF 38%）あり
#
# [2023-02-19]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間189分、出血量361ml。
#
# [2023-03-01]
# 術後化学療法としてDC療法を開始。 心機能低下（EF 35%）あり
#
# [2023-03-18]
# 術後化学療法としてTC療法を開始。
#
# [2023-04-17]
# 術後化学療法としてTCを開始。
# --------------------------------------------------
# ID: 12
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮内膜癌、Stage IVBと診断。
#
# [2023-01-29]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-05]
# 手術記録：開腹子宮全摘施行。手術時間205分、出血量180ml。
# --------------------------------------------------
# ID: 13
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、体部類内膜癌、Stage IVAと診断。
#
# [2023-01-29]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-08]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間179分、出血量293ml。
# --------------------------------------------------
# ID: 14
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、頸部扁平上皮癌、Stage ICと診断。 腎機能低下（Cr 1.6 mg/dl）
#
# [2023-01-18]
# 治療方針：開腹子宮全摘出術の方針。 高度肥満（BMI 35.0）
#
# [2023-02-15]
# 手術記録：開腹子宮摘出術施行。手術時間189分、出血量122ml。
#
# [2023-02-22]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 15
# テキスト:
# [2023-01-01]
# 生検の結果、子宮体部類内膜癌、Stage IBと診断。
#
# [2023-01-30]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-22]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間145分、出血量685ml。
#
# [2023-03-12]
# 術後化学療法としてTCを開始。 抗凝固薬（イグザレルト）服用中
# --------------------------------------------------
# ID: 16
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮体部類内膜癌、Stage IIIAと診断。
#
# [2023-01-31]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-13]
# 手術記録：開腹子宮摘出術施行。手術時間313分、出血量946ml。
#
# [2023-02-24]
# 術後化学療法としてTCを開始。
#
# [2023-03-20]
# 術後化学療法としてDTX+CBDCAを開始。
#
# [2023-04-01]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-04-15]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 17
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、頸部扁平上皮癌、Stage IIICと診断。
#
# [2023-01-21]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-01-29]
# 手術記録：腹腔鏡下全摘術施行。手術時間146分、出血量216ml。
# --------------------------------------------------
# ID: 18
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮頸がん、Stage IVCと診断。 抗凝固薬（エリキュース）服用中
#
# [2023-01-29]
# 治療方針：腹腔鏡下全摘術の方針。 高度肥満（BMI 39.2）
#
# [2023-02-11]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間204分、出血量409ml。
#
# [2023-02-28]
# 術後化学療法としてTC療法を開始。
#
# [2023-03-22]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 19
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮体部類内膜癌、Stage IICと診断。
#
# [2023-01-08]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-03]
# 手術記録：開腹子宮全摘出術施行。手術時間162分、出血量970ml。
#
# [2023-02-12]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 心機能低下（EF 52%）あり
#
# [2023-03-14]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
#
# [2023-03-27]
# 術後化学療法としてDCを開始。
#
# [2023-04-12]
# 術後化学療法としてTC療法を開始。
# --------------------------------------------------
# ID: 20
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頸部癌、Stage IIIAと診断。
#
# [2023-01-18]
# 治療方針：開腹子宮摘出術の方針。 高度肥満（BMI 32.5）
#
# [2023-02-05]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間281分、出血量406ml。
#
# [2023-02-19]
# 術後化学療法としてTCを開始。
#
# [2023-03-07]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-04-04]
# 術後化学療法としてDC療法を開始。 腎機能低下（Cr 2.1 mg/dl）
#
# [2023-04-24]
# 術後化学療法としてDC療法を開始。
# --------------------------------------------------
# ID: 21
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、漿液性卵巣癌、Stage IVAと診断。
#
# [2023-01-11]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。 腎機能低下（Cr 2.8 mg/dl）
#
# [2023-01-20]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間130分、出血量903ml。
#
# [2023-02-18]
# 術後化学療法としてwPTXを開始。 心機能低下（EF 39%）あり
#
# [2023-03-02]
# 術後化学療法としてDC療法を開始。
#
# [2023-03-28]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
#
# [2023-04-25]
# 術後化学療法としてDC療法を開始。
# --------------------------------------------------
# ID: 22
# テキスト:
# [2023-01-01]
# 生検の結果、子宮体がん、Stage IVCと診断。
#
# [2023-01-24]
# 治療方針：開腹子宮摘出術の方針。 高度肥満（BMI 34.2）
#
# [2023-02-19]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間225分、出血量170ml。
#
# [2023-03-09]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-03-22]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-04-15]
# 術後化学療法としてweekly パクリタキセルを開始。 抗凝固薬（エリキュース）服用中
# --------------------------------------------------
# ID: 23
# テキスト:
# [2023-01-01]
# 生検の結果、頚部腺癌、Stage IIICと診断。
#
# [2023-01-20]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-07]
# 手術記録：開腹子宮摘出術施行。手術時間159分、出血量320ml。
#
# [2023-03-08]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-03-29]
# 術後化学療法として毎週パクリタキセルを開始。 腎機能低下（Cr 1.7 mg/dl）
#
# [2023-04-24]
# 術後化学療法としてPTX+CBDCAを開始。 腎機能低下（Cr 2.1 mg/dl）
# --------------------------------------------------
# ID: 24
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頚癌、Stage IIBと診断。 抗凝固薬（ワーファリン）服用中
#
# [2023-01-15]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-01-23]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間130分、出血量128ml。
#
# [2023-02-17]
# 術後化学療法としてweekly PTXを開始。 心機能低下（EF 45%）あり
#
# [2023-03-14]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-03-22]
# 術後化学療法としてwPTXを開始。
#
# [2023-04-13]
# 術後化学療法としてDCを開始。
# --------------------------------------------------
# ID: 25
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部類内膜癌、Stage IICと診断。
#
# [2023-01-26]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-25]
# 手術記録：開腹子宮全摘施行。手術時間203分、出血量724ml。
#
# [2023-03-10]
# 術後化学療法としてDC療法を開始。
# --------------------------------------------------
# ID: 26
# テキスト:
# [2023-01-01]
# 組織生検の結果、頚部腺癌、Stage IIAと診断。
#
# [2023-01-19]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-02-10]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間264分、出血量695ml。
#
# [2023-02-19]
# 術後化学療法としてDC療法を開始。
#
# [2023-03-21]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
#
# [2023-03-28]
# 術後化学療法としてweekly パクリタキセルを開始。
# --------------------------------------------------
# ID: 27
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮体部癌、Stage IBと診断。
#
# [2023-01-25]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-03]
# 手術記録：開腹子宮全摘出術施行。手術時間326分、出血量543ml。
#
# [2023-02-22]
# 術後化学療法としてDCを開始。 心機能低下（EF 46%）あり
#
# [2023-03-04]
# 術後化学療法としてDCを開始。
# --------------------------------------------------
# ID: 28
# テキスト:
# [2023-01-01]
# 組織診断の結果、高異型度漿液性癌、Stage IVBと診断。
#
# [2023-01-09]
# 治療方針：腹腔鏡下子宮全摘出術の方針。 糖尿病（HbA1c 9.8%）あり
#
# [2023-01-29]
# 手術記録：開腹子宮全摘施行。手術時間339分、出血量516ml。
#
# [2023-02-20]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 抗凝固薬（ワーファリン）服用中
#
# [2023-03-07]
# 術後化学療法としてDCを開始。
#
# [2023-03-27]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-04-23]
# 術後化学療法としてweekly PTXを開始。
# --------------------------------------------------
# ID: 29
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頸がん、Stage IICと診断。
#
# [2023-01-30]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-09]
# 手術記録：開腹子宮全摘出術施行。手術時間247分、出血量127ml。
#
# [2023-03-01]
# 術後化学療法としてPTX+CBDCAを開始。 心機能低下（EF 37%）あり
#
# [2023-03-21]
# 術後化学療法としてDTX+CBDCAを開始。
#
# [2023-04-20]
# 術後化学療法として毎週パクリタキセルを開始。 抗凝固薬（エリキュース）服用中
#
# [2023-05-16]
# 術後化学療法としてDCを開始。
# --------------------------------------------------
# ID: 30
# テキスト:
# [2023-01-01]
# 生検の結果、卵巣がん、Stage IIIAと診断。
#
# [2023-01-20]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-16]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間318分、出血量644ml。
#
# [2023-03-18]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-03-29]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 31
# テキスト:
# [2023-01-01]
# 生検の結果、体部類内膜癌、Stage IICと診断。
#
# [2023-01-17]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-05]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間295分、出血量223ml。
#
# [2023-02-13]
# 術後化学療法としてTC療法を開始。
#
# [2023-03-02]
# 術後化学療法としてwPTXを開始。
#
# [2023-03-17]
# 術後化学療法としてDTX+CBDCAを開始。
# --------------------------------------------------
# ID: 32
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、卵巣癌、Stage IIAと診断。
#
# [2023-01-22]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。 糖尿病（HbA1c 9.2%）あり
#
# [2023-02-13]
# 手術記録：開腹子宮全摘施行。手術時間137分、出血量607ml。
#
# [2023-02-23]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-03-13]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
#
# [2023-03-25]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 33
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮頸がん、Stage IVAと診断。 抗凝固薬（イグザレルト）服用中
#
# [2023-01-14]
# 治療方針：開腹全摘術の方針。 抗凝固薬（イグザレルト）服用中
#
# [2023-01-22]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間348分、出血量176ml。
# --------------------------------------------------
# ID: 34
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頸癌、Stage IVCと診断。
#
# [2023-01-09]
# 治療方針：腹腔鏡下子宮全摘出術の方針。 高度肥満（BMI 30.2）
#
# [2023-01-21]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間223分、出血量442ml。
#
# [2023-01-28]
# 術後化学療法としてDC療法を開始。 心機能低下（EF 46%）あり
#
# [2023-02-14]
# 術後化学療法としてDCを開始。
#
# [2023-03-04]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 腎機能低下（Cr 2.7 mg/dl）
#
# [2023-03-31]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 糖尿病（HbA1c 8.9%）あり
# --------------------------------------------------
# ID: 35
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頸癌、Stage ICと診断。 高度肥満（BMI 34.8）
#
# [2023-01-21]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-10]
# 手術記録：開腹全摘術施行。手術時間132分、出血量152ml。
#
# [2023-03-12]
# 術後化学療法としてweekly パクリタキセルを開始。
# --------------------------------------------------
# ID: 36
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮頸癌、Stage IIBと診断。
#
# [2023-01-16]
# 治療方針：開腹子宮全摘の方針。
#
# [2023-02-08]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間340分、出血量500ml。
# --------------------------------------------------
# ID: 37
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮体部癌、Stage IVAと診断。
#
# [2023-01-30]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-02-13]
# 手術記録：腹腔鏡下全摘術施行。手術時間285分、出血量519ml。
# --------------------------------------------------
# ID: 38
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、高異型度漿液性癌、Stage IAと診断。
#
# [2023-01-17]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-02-12]
# 手術記録：開腹子宮全摘出術施行。手術時間222分、出血量907ml。
# --------------------------------------------------
# ID: 39
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部類内膜癌、Stage IAと診断。 心機能低下（EF 50%）あり
#
# [2023-01-28]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-02-05]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間295分、出血量917ml。
#
# [2023-02-17]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 40
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、頸部扁平上皮癌、Stage IBと診断。
#
# [2023-01-27]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-05]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間359分、出血量869ml。
# --------------------------------------------------
# ID: 41
# テキスト:
# [2023-01-01]
# 生検の結果、明細胞癌、Stage IVBと診断。 腎機能低下（Cr 2.6 mg/dl）
#
# [2023-01-29]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-08]
# 手術記録：開腹子宮摘出術施行。手術時間344分、出血量73ml。
#
# [2023-02-27]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 高度肥満（BMI 32.8）
#
# [2023-03-12]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 腎機能低下（Cr 2.9 mg/dl）
#
# [2023-04-07]
# 術後化学療法としてTCを開始。 腎機能低下（Cr 2.3 mg/dl）
# --------------------------------------------------
# ID: 42
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮体部類内膜癌、Stage IBと診断。
#
# [2023-01-17]
# 治療方針：腹腔鏡下子宮摘出術の方針。
#
# [2023-02-07]
# 手術記録：腹腔鏡下全摘術施行。手術時間148分、出血量579ml。
#
# [2023-02-27]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 43
# テキスト:
# [2023-01-01]
# 生検の結果、子宮内膜癌、Stage ICと診断。
#
# [2023-01-31]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-03-02]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間302分、出血量679ml。
#
# [2023-03-24]
# 術後化学療法としてDC療法を開始。
# --------------------------------------------------
# ID: 44
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮頸癌、Stage IBと診断。
#
# [2023-01-21]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-01-29]
# 手術記録：開腹子宮全摘施行。手術時間329分、出血量76ml。
#
# [2023-02-17]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 45
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、卵巣癌、Stage IIIAと診断。
#
# [2023-01-21]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-13]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間264分、出血量423ml。
#
# [2023-03-06]
# 術後化学療法としてwPTXを開始。
#
# [2023-04-03]
# 術後化学療法としてweekly パクリタキセルを開始。
# --------------------------------------------------
# ID: 46
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頸がん、Stage IAと診断。 心機能低下（EF 38%）あり
#
# [2023-01-08]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-01-31]
# 手術記録：腹腔鏡下全摘術施行。手術時間146分、出血量313ml。
#
# [2023-02-17]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-03-14]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 47
# テキスト:
# [2023-01-01]
# 組織診の結果、頸部扁平上皮癌、Stage IIBと診断。
#
# [2023-01-16]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-05]
# 手術記録：開腹全摘術施行。手術時間138分、出血量755ml。
# --------------------------------------------------
# ID: 48
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、卵巣癌、Stage IICと診断。
#
# [2023-01-30]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-14]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間347分、出血量574ml。
#
# [2023-03-11]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-03-21]
# 術後化学療法としてDCを開始。
# --------------------------------------------------
# ID: 49
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮体がん、Stage IIAと診断。 糖尿病（HbA1c 7.6%）あり
#
# [2023-01-24]
# 治療方針：開腹子宮全摘の方針。
#
# [2023-02-16]
# 手術記録：腹腔鏡下全摘術施行。手術時間184分、出血量779ml。
#
# [2023-03-01]
# 術後化学療法としてTC療法を開始。
# --------------------------------------------------
# ID: 50
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頸がん、Stage IAと診断。
#
# [2023-01-12]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-07]
# 手術記録：開腹全摘術施行。手術時間220分、出血量59ml。
# --------------------------------------------------
# ID: 51
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮体癌、Stage IVBと診断。 高度肥満（BMI 36.2）
#
# [2023-01-16]
# 治療方針：開腹子宮全摘出術の方針。
#
# [2023-02-11]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間299分、出血量431ml。
#
# [2023-03-08]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-04-05]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 52
# テキスト:
# [2023-01-01]
# 組織診断の結果、頚部腺癌、Stage IVBと診断。
#
# [2023-01-11]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-01-28]
# 手術記録：腹腔鏡下全摘術施行。手術時間216分、出血量450ml。
#
# [2023-02-18]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-03-05]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-04-03]
# 術後化学療法としてweekly PTXを開始。
# --------------------------------------------------
# ID: 53
# テキスト:
# [2023-01-01]
# 組織診断の結果、卵巣がん、Stage IVCと診断。 心機能低下（EF 38%）あり
#
# [2023-01-25]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-19]
# 手術記録：開腹子宮摘出術施行。手術時間132分、出血量284ml。
# --------------------------------------------------
# ID: 54
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮頸がん、Stage ICと診断。 腎機能低下（Cr 1.5 mg/dl）
#
# [2023-01-18]
# 治療方針：開腹子宮全摘出術の方針。
#
# [2023-02-10]
# 手術記録：開腹子宮全摘施行。手術時間228分、出血量631ml。
#
# [2023-03-08]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-03-24]
# 術後化学療法としてDCを開始。 抗凝固薬（エリキュース）服用中
#
# [2023-04-11]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 55
# テキスト:
# [2023-01-01]
# 組織生検の結果、卵巣がん、Stage IIBと診断。
#
# [2023-01-18]
# 治療方針：腹腔鏡下子宮摘出術の方針。 糖尿病（HbA1c 8.3%）あり
#
# [2023-01-30]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間266分、出血量211ml。
#
# [2023-02-08]
# 術後化学療法としてDC療法を開始。
#
# [2023-02-25]
# 術後化学療法としてDCを開始。 腎機能低下（Cr 1.5 mg/dl）
#
# [2023-03-18]
# 術後化学療法としてwPTXを開始。 糖尿病（HbA1c 8.9%）あり
# --------------------------------------------------
# ID: 56
# テキスト:
# [2023-01-01]
# 生検の結果、卵巣がん、Stage IIIBと診断。 心機能低下（EF 30%）あり
#
# [2023-01-25]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-16]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間207分、出血量335ml。
#
# [2023-03-03]
# 術後化学療法としてTCを開始。 心機能低下（EF 48%）あり
#
# [2023-03-27]
# 術後化学療法としてTCを開始。
#
# [2023-04-16]
# 術後化学療法としてTCを開始。 腎機能低下（Cr 2.3 mg/dl）
#
# [2023-04-29]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 57
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮内膜癌、Stage IIAと診断。 心機能低下（EF 37%）あり
#
# [2023-01-28]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-12]
# 手術記録：開腹子宮全摘出術施行。手術時間136分、出血量991ml。
#
# [2023-02-26]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 58
# テキスト:
# [2023-01-01]
# 組織診断の結果、卵巣癌、Stage IIICと診断。 高度肥満（BMI 33.7）
#
# [2023-01-17]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-01]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間327分、出血量974ml。
#
# [2023-02-24]
# 術後化学療法としてDC療法を開始。 心機能低下（EF 32%）あり
#
# [2023-03-25]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 59
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体癌、Stage IVBと診断。
#
# [2023-01-28]
# 治療方針：開腹全摘術の方針。 糖尿病（HbA1c 6.8%）あり
#
# [2023-02-15]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間142分、出血量899ml。
# --------------------------------------------------
# ID: 60
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頸部癌、Stage ICと診断。 糖尿病（HbA1c 8.2%）あり
#
# [2023-01-23]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-19]
# 手術記録：開腹全摘術施行。手術時間308分、出血量510ml。
#
# [2023-03-07]
# 術後化学療法としてTC療法を開始。
#
# [2023-03-16]
# 術後化学療法としてTC療法を開始。
#
# [2023-03-28]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-04-09]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 61
# テキスト:
# [2023-01-01]
# 生検の結果、体部類内膜癌、Stage IIIBと診断。
#
# [2023-01-11]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-01-22]
# 手術記録：開腹子宮全摘施行。手術時間256分、出血量415ml。
# --------------------------------------------------
# ID: 62
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮内膜癌、Stage IIBと診断。
#
# [2023-01-17]
# 治療方針：開腹子宮全摘出術の方針。
#
# [2023-02-04]
# 手術記録：開腹全摘術施行。手術時間338分、出血量714ml。
#
# [2023-03-06]
# 術後化学療法としてwPTXを開始。 糖尿病（HbA1c 7.7%）あり
#
# [2023-03-18]
# 術後化学療法としてDCを開始。
#
# [2023-04-06]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 63
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頸部癌、Stage IIIAと診断。 高度肥満（BMI 33.3）
#
# [2023-01-15]
# 治療方針：開腹全摘術の方針。 抗凝固薬（プラザキサ）服用中
#
# [2023-02-07]
# 手術記録：腹腔鏡下全摘術施行。手術時間331分、出血量558ml。
#
# [2023-03-03]
# 術後化学療法として毎週パクリタキセルを開始。 心機能低下（EF 54%）あり
#
# [2023-03-24]
# 術後化学療法としてPTX+CBDCAを開始。 抗凝固薬（プラザキサ）服用中
# --------------------------------------------------
# ID: 64
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部癌、Stage IIBと診断。
#
# [2023-01-29]
# 治療方針：腹腔鏡下子宮全摘の方針。 高度肥満（BMI 39.4）
#
# [2023-02-12]
# 手術記録：開腹全摘術施行。手術時間154分、出血量972ml。
#
# [2023-03-09]
# 術後化学療法としてTCを開始。
#
# [2023-04-04]
# 術後化学療法としてweekly パクリタキセルを開始。 腎機能低下（Cr 2.5 mg/dl）
#
# [2023-04-27]
# 術後化学療法としてDCを開始。 抗凝固薬（プラザキサ）服用中
# --------------------------------------------------
# ID: 65
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、体部類内膜癌、Stage IVAと診断。
#
# [2023-01-23]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-10]
# 手術記録：腹腔鏡下全摘術施行。手術時間130分、出血量396ml。
#
# [2023-03-04]
# 術後化学療法としてweekly PTXを開始。 心機能低下（EF 54%）あり
#
# [2023-03-21]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 抗凝固薬（エリキュース）服用中
#
# [2023-04-03]
# 術後化学療法としてDCを開始。
# --------------------------------------------------
# ID: 66
# テキスト:
# [2023-01-01]
# 組織生検の結果、卵巣がん、Stage IIBと診断。 高度肥満（BMI 39.1）
#
# [2023-01-14]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-05]
# 手術記録：開腹子宮全摘施行。手術時間271分、出血量332ml。
#
# [2023-03-06]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。
#
# [2023-03-30]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-04-29]
# 術後化学療法としてDC療法を開始。 腎機能低下（Cr 2.5 mg/dl）
# --------------------------------------------------
# ID: 67
# テキスト:
# [2023-01-01]
# 生検の結果、明細胞癌、Stage IAと診断。 糖尿病（HbA1c 8.4%）あり
#
# [2023-01-14]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-08]
# 手術記録：開腹子宮全摘施行。手術時間266分、出血量100ml。
# --------------------------------------------------
# ID: 68
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、卵巣腫瘍、Stage IIBと診断。
#
# [2023-01-15]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-01-30]
# 手術記録：腹腔鏡下全摘術施行。手術時間334分、出血量337ml。
# --------------------------------------------------
# ID: 69
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、卵巣腫瘍、Stage IVAと診断。
#
# [2023-01-08]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-07]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間248分、出血量87ml。
#
# [2023-03-02]
# 術後化学療法としてTCを開始。 糖尿病（HbA1c 8.2%）あり
# --------------------------------------------------
# ID: 70
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮頸がん、Stage IBと診断。
#
# [2023-01-23]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。 心機能低下（EF 33%）あり
#
# [2023-02-07]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間344分、出血量220ml。
#
# [2023-02-26]
# 術後化学療法としてwPTXを開始。
# --------------------------------------------------
# ID: 71
# テキスト:
# [2023-01-01]
# 組織生検の結果、頚部腺癌、Stage IBと診断。
#
# [2023-01-31]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-19]
# 手術記録：開腹子宮全摘施行。手術時間329分、出血量623ml。
#
# [2023-03-03]
# 術後化学療法としてweekly PTXを開始。
# --------------------------------------------------
# ID: 72
# テキスト:
# [2023-01-01]
# 組織診の結果、高異型度漿液性癌、Stage IIIBと診断。 抗凝固薬（ワーファリン）服用中
#
# [2023-01-16]
# 治療方針：腹腔鏡下全摘術の方針。
#
# [2023-02-10]
# 手術記録：開腹全摘術施行。手術時間329分、出血量528ml。
#
# [2023-02-17]
# 術後化学療法としてPTX+CBDCAを開始。 糖尿病（HbA1c 8.7%）あり
# --------------------------------------------------
# ID: 73
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、卵巣腫瘍、Stage IIICと診断。
#
# [2023-01-10]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。 高度肥満（BMI 39.1）
#
# [2023-01-25]
# 手術記録：開腹子宮全摘施行。手術時間356分、出血量583ml。
# --------------------------------------------------
# ID: 74
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部癌、Stage IBと診断。 腎機能低下（Cr 2.6 mg/dl）
#
# [2023-01-08]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-01-15]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間234分、出血量695ml。
#
# [2023-02-12]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-02-25]
# 術後化学療法としてPTX+CBDCAを開始。 高度肥満（BMI 30.8）
# --------------------------------------------------
# ID: 75
# テキスト:
# [2023-01-01]
# 生検の結果、頚部腺癌、Stage IICと診断。
#
# [2023-01-22]
# 治療方針：腹腔鏡下全摘術の方針。 抗凝固薬（ワーファリン）服用中
#
# [2023-02-13]
# 手術記録：開腹全摘術施行。手術時間168分、出血量467ml。
# --------------------------------------------------
# ID: 76
# テキスト:
# [2023-01-01]
# 生検の結果、卵巣腫瘍、Stage IAと診断。 高度肥満（BMI 30.8）
#
# [2023-01-21]
# 治療方針：開腹全摘術の方針。
#
# [2023-01-31]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間352分、出血量700ml。
#
# [2023-02-19]
# 術後化学療法としてTC療法を開始。 腎機能低下（Cr 1.7 mg/dl）
# --------------------------------------------------
# ID: 77
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮頸癌、Stage IVBと診断。 腎機能低下（Cr 2.2 mg/dl）
#
# [2023-01-26]
# 治療方針：開腹子宮全摘の方針。
#
# [2023-02-16]
# 手術記録：腹腔鏡下全摘術施行。手術時間196分、出血量389ml。
#
# [2023-03-09]
# 術後化学療法としてTC療法を開始。
#
# [2023-03-16]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-04-07]
# 術後化学療法としてDCを開始。 糖尿病（HbA1c 6.9%）あり
#
# [2023-05-05]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 78
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、頸部扁平上皮癌、Stage IVCと診断。 腎機能低下（Cr 2.5 mg/dl）
#
# [2023-01-28]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-15]
# 手術記録：開腹子宮全摘出術施行。手術時間231分、出血量547ml。
#
# [2023-03-12]
# 術後化学療法としてDC療法を開始。
#
# [2023-03-20]
# 術後化学療法としてTC療法を開始。
#
# [2023-04-12]
# 術後化学療法として毎週パクリタキセルを開始。 高度肥満（BMI 36.9）
#
# [2023-04-29]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 79
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮内膜癌、Stage ICと診断。 抗凝固薬（ワーファリン）服用中
#
# [2023-01-08]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-01-29]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間163分、出血量564ml。
#
# [2023-02-13]
# 術後化学療法としてDC療法を開始。
#
# [2023-02-26]
# 術後化学療法としてwPTXを開始。 糖尿病（HbA1c 7.2%）あり
# --------------------------------------------------
# ID: 80
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮体癌、Stage IBと診断。
#
# [2023-01-20]
# 治療方針：腹腔鏡下子宮摘出術の方針。
#
# [2023-02-04]
# 手術記録：腹腔鏡下全摘術施行。手術時間221分、出血量956ml。
#
# [2023-02-13]
# 術後化学療法としてDC療法を開始。
#
# [2023-03-09]
# 術後化学療法としてDC療法を開始。
#
# [2023-04-06]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 高度肥満（BMI 33.1）
# --------------------------------------------------
# ID: 81
# テキスト:
# [2023-01-01]
# 生検の結果、子宮頸がん、Stage IIAと診断。 抗凝固薬（ワーファリン）服用中
#
# [2023-01-24]
# 治療方針：開腹子宮全摘出術の方針。 抗凝固薬（エリキュース）服用中
#
# [2023-02-13]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間289分、出血量294ml。
#
# [2023-03-06]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。 腎機能低下（Cr 2.6 mg/dl）
#
# [2023-03-23]
# 術後化学療法としてTC療法を開始。
# --------------------------------------------------
# ID: 82
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮頚癌、Stage IVBと診断。 高度肥満（BMI 39.4）
#
# [2023-01-25]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。 高度肥満（BMI 33.0）
#
# [2023-02-14]
# 手術記録：開腹子宮全摘施行。手術時間297分、出血量922ml。
#
# [2023-02-28]
# 術後化学療法としてDTX+CBDCAを開始。
# --------------------------------------------------
# ID: 83
# テキスト:
# [2023-01-01]
# 組織診断の結果、卵巣がん、Stage ICと診断。 心機能低下（EF 39%）あり
#
# [2023-01-30]
# 治療方針：開腹子宮全摘出術の方針。
#
# [2023-02-10]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間172分、出血量369ml。
#
# [2023-03-06]
# 術後化学療法としてTC療法を開始。 腎機能低下（Cr 2.4 mg/dl）
# --------------------------------------------------
# ID: 84
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頚癌、Stage IICと診断。
#
# [2023-01-24]
# 治療方針：開腹子宮全摘出術の方針。
#
# [2023-02-23]
# 手術記録：腹腔鏡下子宮全摘施行。手術時間246分、出血量937ml。
#
# [2023-03-21]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 85
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮体がん、Stage IIICと診断。
#
# [2023-01-17]
# 治療方針：開腹子宮全摘出術の方針。 心機能低下（EF 33%）あり
#
# [2023-01-31]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間343分、出血量59ml。
# --------------------------------------------------
# ID: 86
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮頸部癌、Stage IIIBと診断。
#
# [2023-01-29]
# 治療方針：腹腔鏡下子宮摘出術の方針。
#
# [2023-02-28]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間335分、出血量872ml。
#
# [2023-03-20]
# 術後化学療法としてTCを開始。 抗凝固薬（プラザキサ）服用中
#
# [2023-04-10]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-04-24]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。 腎機能低下（Cr 2.5 mg/dl）
# --------------------------------------------------
# ID: 87
# テキスト:
# [2023-01-01]
# 組織診の結果、体部類内膜癌、Stage IIIAと診断。 高度肥満（BMI 36.5）
#
# [2023-01-22]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-05]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間331分、出血量309ml。
#
# [2023-02-20]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 88
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、卵巣癌、Stage IIIAと診断。 高度肥満（BMI 32.7）
#
# [2023-01-21]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-19]
# 手術記録：開腹子宮摘出術施行。手術時間349分、出血量624ml。
#
# [2023-03-10]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-03-25]
# 術後化学療法としてweekly PTXを開始。
# --------------------------------------------------
# ID: 89
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮体がん、Stage IIIBと診断。
#
# [2023-01-12]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-09]
# 手術記録：開腹子宮摘出術施行。手術時間356分、出血量685ml。
#
# [2023-02-22]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-03-10]
# 術後化学療法としてDC療法を開始。 糖尿病（HbA1c 8.3%）あり
#
# [2023-03-21]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-04-04]
# 術後化学療法としてwPTXを開始。 糖尿病（HbA1c 7.2%）あり
# --------------------------------------------------
# ID: 90
# テキスト:
# [2023-01-01]
# 病理組織診断の結果、子宮頸癌、Stage IIAと診断。 高度肥満（BMI 30.6）
#
# [2023-01-19]
# 治療方針：腹腔鏡下子宮全摘+両側付属器切除術の方針。
#
# [2023-02-11]
# 手術記録：開腹子宮全摘施行。手術時間307分、出血量682ml。
# --------------------------------------------------
# ID: 91
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部類内膜癌、Stage ICと診断。
#
# [2023-01-12]
# 治療方針：開腹子宮全摘+両側付属器切除術の方針。
#
# [2023-01-24]
# 手術記録：開腹全摘術施行。手術時間320分、出血量479ml。
#
# [2023-02-23]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-03-11]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 92
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、頚部腺癌、Stage IIICと診断。 高度肥満（BMI 39.2）
#
# [2023-01-22]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-02]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間123分、出血量434ml。
#
# [2023-03-02]
# 術後化学療法として毎週パクリタキセルを開始。
#
# [2023-04-01]
# 術後化学療法としてTC療法を開始。
#
# [2023-04-17]
# 術後化学療法として毎週パクリタキセルを開始。
# --------------------------------------------------
# ID: 93
# テキスト:
# [2023-01-01]
# 組織生検の結果、子宮体部類内膜癌、Stage IAと診断。
#
# [2023-01-31]
# 治療方針：腹腔鏡下全摘術の方針。 腎機能低下（Cr 2.7 mg/dl）
#
# [2023-02-24]
# 手術記録：開腹全摘術施行。手術時間234分、出血量299ml。
#
# [2023-03-20]
# 術後化学療法としてTCを開始。 糖尿病（HbA1c 9.2%）あり
#
# [2023-04-03]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 94
# テキスト:
# [2023-01-01]
# 生検の結果、子宮内膜癌、Stage IIBと診断。 糖尿病（HbA1c 6.7%）あり
#
# [2023-01-31]
# 治療方針：開腹子宮全摘の方針。 抗凝固薬（プラザキサ）服用中
#
# [2023-02-24]
# 手術記録：開腹子宮全摘+両側付属器切除術施行。手術時間294分、出血量441ml。
#
# [2023-03-04]
# 術後化学療法としてDC療法を開始。
#
# [2023-03-15]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。
#
# [2023-03-26]
# 術後化学療法としてDCを開始。
#
# [2023-04-07]
# 術後化学療法としてDC療法を開始。
# --------------------------------------------------
# ID: 95
# テキスト:
# [2023-01-01]
# 組織診断の結果、子宮体部類内膜癌、Stage IIIAと診断。 心機能低下（EF 52%）あり
#
# [2023-01-13]
# 治療方針：腹腔鏡下全摘術の方針。 心機能低下（EF 48%）あり
#
# [2023-01-20]
# 手術記録：腹腔鏡下子宮摘出術施行。手術時間242分、出血量612ml。
#
# [2023-02-02]
# 術後化学療法としてweekly PTXを開始。
#
# [2023-02-12]
# 術後化学療法としてTCを開始。 腎機能低下（Cr 2.0 mg/dl）
#
# [2023-03-03]
# 術後化学療法としてパクリタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 96
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、頚部腺癌、Stage IVCと診断。 心機能低下（EF 48%）あり
#
# [2023-01-12]
# 治療方針：開腹子宮摘出術の方針。
#
# [2023-02-02]
# 手術記録：腹腔鏡下子宮全摘+両側付属器切除術施行。手術時間154分、出血量496ml。
#
# [2023-02-21]
# 術後化学療法としてwPTXを開始。
#
# [2023-03-17]
# 術後化学療法としてPTX+CBDCAを開始。
# --------------------------------------------------
# ID: 97
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、体部類内膜癌、Stage IICと診断。 腎機能低下（Cr 2.5 mg/dl）
#
# [2023-01-19]
# 治療方針：腹腔鏡下子宮全摘出術の方針。
#
# [2023-02-08]
# 手術記録：開腹子宮摘出術施行。手術時間128分、出血量813ml。
# --------------------------------------------------
# ID: 98
# テキスト:
# [2023-01-01]
# 組織診の結果、頸部扁平上皮癌、Stage IIIBと診断。
#
# [2023-01-28]
# 治療方針：開腹全摘術の方針。
#
# [2023-02-13]
# 手術記録：開腹子宮全摘出術施行。手術時間201分、出血量372ml。
#
# [2023-03-15]
# 術後化学療法としてTCを開始。
#
# [2023-03-22]
# 術後化学療法としてTCを開始。 高度肥満（BMI 32.1）
#
# [2023-04-07]
# 術後化学療法としてwPTXを開始。
#
# [2023-05-07]
# 術後化学療法としてwPTXを開始。 心機能低下（EF 46%）あり
# --------------------------------------------------
# ID: 99
# テキスト:
# [2023-01-01]
# 内膜組織診の結果、子宮頸癌、Stage IVAと診断。
#
# [2023-01-14]
# 治療方針：開腹全摘術の方針。 糖尿病（HbA1c 6.7%）あり
#
# [2023-01-26]
# 手術記録：腹腔鏡下全摘術施行。手術時間299分、出血量160ml。
#
# [2023-02-11]
# 術後化学療法としてPTX+CBDCAを開始。
#
# [2023-03-07]
# 術後化学療法としてweekly パクリタキセルを開始。
#
# [2023-03-26]
# 術後化学療法としてPTX+CBDCAを開始。 心機能低下（EF 50%）あり
#
# [2023-04-07]
# 術後化学療法としてドセタキセル+カルボプラチンを開始。
# --------------------------------------------------
# ID: 100
# テキスト:
# [2023-01-01]
# 組織診の結果、子宮体がん、Stage IVBと診断。
#
# [2023-01-24]
# 治療方針：腹腔鏡下子宮全摘の方針。
#
# [2023-02-17]
# 手術記録：腹腔鏡下子宮全摘出術施行。手術時間124分、出血量161ml。
#
# [2023-03-14]
# 術後化学療法としてDC療法を開始。
#
# [2023-04-06]
# 術後化学療法としてwPTXを開始。 抗凝固薬（エリキュース）服用中
# --------------------------------------------------

# %% [markdown]
# 使用したい抽出用テンプレートの選択

# %%
# 各種分析の実行
analysis_templates = [
    "cancer_diagnosis",   # がん診断名の抽出
    "cancer_stage",       # ステージ情報の抽出
    "diagnostic_test",    # 診断検査の抽出
    "first_treatment",    # 初回治療情報の抽出
    "chemotherapy_info",  # 抗がん剤治療情報の抽出
    "surgery_type",       # 術式の抽出
    "special_notes"       # 特記事項の抽出
]

# %% [markdown]
# 分析の実行(時間がかかります)

# %%
# 分析の実行
for template in analysis_templates:
    print(f"\n分析実行中: {template}")
    if not analyzer.analyze_with_template(template):
        print(f"警告: {template}の分析に失敗しました")

# 結果の保存
analyzer.save_results("data/analyzed_results.xlsx")
# Out:
# テンプレートを読み込みました（7件）
# ファイルの読み込みが完了しました
# ✅ ファイルの読み込みが完了しました
# データ行数: 489
#
# 列一覧:
# - ID
# - day
# - text
#
# 分析実行中: cancer_diagnosis
# 分析が完了しました。新しい列 '分析結果_がん診断名抽出' が追加されました。
# 分析結果を 'data/analyzed_results.xlsx' に保存しました
#
# 分析結果の概要:
# - 分析結果_がん診断名抽出:
#   総データ数: 489
#   ユニークな値の数: 24
#   未検出(N/A)の数: 0
#   主な抽出結果:
#     - "子宮体部類内膜癌": 77件
#     - "子宮頸がん": 38件
#     - "卵巣がん": 37件
#     - "頚部腺癌": 36件
#     - "子宮頸癌": 35件
# True

# %% [markdown]
# ## 3. 分析結果の確認と保存

# %%
# 分析結果の保存
output_path = "sample_data_analyzed.xlsx"
analyzer.save_results(output_path)

# 結果の確認
results_df = pd.read_excel(output_path)
print("\n分析結果のプレビュー:")
display(results_df.head())
# Out:
# 分析結果を 'sample_data_analyzed.xlsx' に保存しました
#
# 分析結果の概要:
# - 分析結果_がん診断名抽出:
#   総データ数: 489
#   ユニークな値の数: 24
#   未検出(N/A)の数: 0
#   主な抽出結果:
#     - "子宮体部類内膜癌": 77件
#     - "子宮頸がん": 38件
#     - "卵巣がん": 37件
#     - "頚部腺癌": 36件
#     - "子宮頸癌": 35件
#
# 分析結果のプレビュー:
#    ID        day                                           text 分析結果_がん診断名抽出
# 0   1 2023-01-01    組織診の結果、体部類内膜癌、Stage IVBと診断。 抗凝固薬（イグザレルト）服用中   "子宮体部類内膜癌"
# 1   1 2023-01-11                              治療方針：腹腔鏡下子宮全摘の方針。   "子宮体部類内膜癌"
# 2   1 2023-02-10           手術記録：腹腔鏡下子宮全摘出術施行。手術時間187分、出血量214ml。   "子宮体部類内膜癌"
# 3   1 2023-02-20    術後化学療法としてドセタキセル+カルボプラチンを開始。 抗凝固薬（イグザレルト）服用中   "子宮体部類内膜癌"
# 4   1 2023-03-05  術後化学療法としてドセタキセル+カルボプラチンを開始。 糖尿病（HbA1c 9.1%）あり   "子宮体部類内膜癌"

# %% [markdown]
# ## 4. 特定の患者の詳細確認

# %%
def display_patient_details(df, patient_id):
    patient_data = df[df['ID'] == patient_id].sort_values('day')
    print(f"患者ID {patient_id} の経過:")
    
    for _, row in patient_data.iterrows():
        print(f"\n日付: {row['day']}")
        print(f"記録: {row['text']}")
        
        # 分析結果列の表示
        analysis_columns = [col for col in df.columns if col.startswith('分析結果_')]
        for col in analysis_columns:
            if row[col] != 'N/A':
                print(f"{col}: {row[col]}")

# 最初の患者IDについて詳細を表示
first_patient_id = results_df['ID'].iloc[0]
display_patient_details(results_df, first_patient_id)
# Out:
# 患者ID 1 の経過:
#
# 日付: 2023-01-01 00:00:00
# 記録: 組織診の結果、体部類内膜癌、Stage IVBと診断。 抗凝固薬（イグザレルト）服用中
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
#
# 日付: 2023-01-11 00:00:00
# 記録: 治療方針：腹腔鏡下子宮全摘の方針。
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
#
# 日付: 2023-02-10 00:00:00
# 記録: 手術記録：腹腔鏡下子宮全摘出術施行。手術時間187分、出血量214ml。
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
#
# 日付: 2023-02-20 00:00:00
# 記録: 術後化学療法としてドセタキセル+カルボプラチンを開始。 抗凝固薬（イグザレルト）服用中
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
#
# 日付: 2023-03-05 00:00:00
# 記録: 術後化学療法としてドセタキセル+カルボプラチンを開始。 糖尿病（HbA1c 9.1%）あり
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
#
# 日付: 2023-03-13 00:00:00
# 記録: 術後化学療法として毎週パクリタキセルを開始。 心機能低下（EF 55%）あり
# 分析結果_がん診断名抽出: "子宮体部類内膜癌"
